# %% [markdown]
# # 1.環境構築

# %% [markdown]
# ## 1.1ライブラリのインストール

# %%
# langcahianライブラリのインストール
# !pip install langchain langchain-community

# openaiライブラリのインストール
# !pip install openai

# lnagchainでopenaiを使うためのライブラリをインストール
# !pip install langchain_openai

 #pdfを読み込むためのライブラリをインストールする
# !pip install pypdf

# embeddingで利用するライブラリのインストール
# !pip install tiktoken

# ローカルマシン上で実行できるchromaベクターデータベースのインストール
# !pip install chromadb

# 簡単なGUIを作成できるライブラリのインストール
# !pip install gradio
# Out:
# Requirement already satisfied: langchain in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (0.2.16)
# Requirement already satisfied: langchain-community in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (0.2.16)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain) (3.10.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain) (0.2.38)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain) (0.1.114)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.11)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: anyio in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.4.0)
# Requirement already satisfied: httpcore==1.* in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openai in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (1.43.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.8)
# Requirement already satisfied: certifi in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: colorama in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain_openai in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (0.1.23)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.35 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain_openai) (0.2.38)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain_openai) (1.43.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain_openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain_openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain_openai) (0.1.114)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain_openai) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain_openai) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain_openai) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain_openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (0.5.0)
# Requirement already satisfied: sniffio in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (4.66.5)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.7.24)
# Requirement already satisfied: requests>=2.26.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain_openai) (3.8)
# Requirement already satisfied: certifi in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain_openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain_openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.35->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.35->langchain_openai) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3.0,>=0.2.35->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3.0,>=0.2.35->langchain_openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (2.2.2)
# Requirement already satisfied: colorama in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.40.0->langchain_openai) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pypdf in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (4.3.1)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tiktoken in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from tiktoken) (2024.7.24)
# Requirement already satisfied: requests>=2.26.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests>=2.26.0->tiktoken) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests>=2.26.0->tiktoken) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests>=2.26.0->tiktoken) (2024.8.30)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting chromadb
#   Using cached chromadb-0.5.5-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (2.8.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (0.112.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.6)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.6.3-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.19.2-cp312-cp312-win_amd64.whl.metadata (4.7 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Using cached tokenizers-0.20.0-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (4.66.5)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (6.4.4)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (1.66.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (0.12.5)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-30.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-4.1.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: packaging>=19.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.38.4)
# Requirement already satisfied: anyio in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (4.4.0)
# Requirement already satisfied: certifi in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: idna in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (3.8)
# Requirement already satisfied: sniffio in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.34.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.2)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: protobuf in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.28.0)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb)
#   Using cached sympy-1.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<=8.4.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Using cached protobuf-4.25.4-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_util_http-0.48b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: setuptools>=16.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (74.1.2)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: asgiref~=3.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pydantic>=1.9->chromadb) (2.20.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.24.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (13.8.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.1-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-0.24.0-cp312-none-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.9.0)
# Collecting zipp>=0.5 (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Using cached zipp-3.20.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.18.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.4.1-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Using cached chromadb-0.5.5-py3-none-any.whl (584 kB)
# Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
# Using cached build-1.2.1-py3-none-any.whl (21 kB)
# Using cached kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
# Using cached mmh3-4.1.0-cp312-cp312-win_amd64.whl (31 kB)
# Using cached onnxruntime-1.19.2-cp312-cp312-win_amd64.whl (11.1 MB)
# Using cached opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl (11 kB)
# Using cached opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Using cached opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Using cached opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
# Using cached opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached posthog-3.6.3-py2.py3-none-any.whl (53 kB)
# Using cached tokenizers-0.20.0-cp312-none-win_amd64.whl (2.3 MB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached google_auth-2.34.0-py2.py3-none-any.whl (200 kB)
# Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Using cached httptools-0.6.1-cp312-cp312-win_amd64.whl (55 kB)
# Using cached importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached protobuf-4.25.4-cp310-abi3-win_amd64.whl (413 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached watchfiles-0.24.0-cp312-none-win_amd64.whl (277 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached sympy-1.13.2-py3-none-any.whl (6.2 MB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Using cached zipp-3.20.1-py3-none-any.whl (9.0 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'done'
#   Created wheel for chroma-hnswlib: filename=chroma_hnswlib-0.7.6-cp312-cp312-win_amd64.whl size=153805 sha256=7b453345f61150e3240f36e9361f31841c997888e176c2aeee085c7aa01d9c4d
#   Stored in directory: c:\users\iniad\appdata\local\pip\cache\wheels\28\29\0e\934c768c2e673547ec6e947e821346f4ed691a089fe046743f
# Successfully built chroma-hnswlib
# Installing collected packages: pyreadline3, pypika, mpmath, monotonic, mmh3, flatbuffers, zipp, wrapt, websocket-client, sympy, python-dotenv, pyproject_hooks, pyasn1, protobuf, overrides, opentelemetry-util-http, oauthlib, humanfriendly, httptools, chroma-hnswlib, cachetools, bcrypt, backoff, watchfiles, rsa, requests-oauthlib, pyasn1-modules, posthog, opentelemetry-proto, importlib-metadata, googleapis-common-protos, deprecated, coloredlogs, build, tokenizers, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, google-auth, opentelemetry-semantic-conventions, opentelemetry-instrumentation, kubernetes, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.28.0
#     Uninstalling protobuf-5.28.0:
#       Successfully uninstalled protobuf-5.28.0
# Successfully installed backoff-2.2.1 bcrypt-4.2.0 build-1.2.1 cachetools-5.5.0 chroma-hnswlib-0.7.6 chromadb-0.5.5 coloredlogs-15.0.1 deprecated-1.2.14 flatbuffers-24.3.25 google-auth-2.34.0 googleapis-common-protos-1.65.0 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-8.4.0 kubernetes-30.1.0 mmh3-4.1.0 monotonic-1.6 mpmath-1.3.0 oauthlib-3.2.2 onnxruntime-1.19.2 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 overrides-7.7.0 posthog-3.6.3 protobuf-4.25.4 pyasn1-0.6.0 pyasn1-modules-0.4.0 pypika-0.48.9 pyproject_hooks-1.1.0 pyreadline3-3.4.1 python-dotenv-1.0.1 requests-oauthlib-2.0.0 rsa-4.9 sympy-1.13.2 tokenizers-0.20.0 watchfiles-0.24.0 websocket-client-1.8.0 wrapt-1.16.0 zipp-3.20.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-tools 1.66.1 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.4 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gradio in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (4.42.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (4.4.0)
# Requirement already satisfied: fastapi in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (0.112.2)
# Requirement already satisfied: ffmpy in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.3.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (0.24.6)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (6.4.4)
# Requirement already satisfied: jinja2<4.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (3.9.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (3.10.7)
# Requirement already satisfied: packaging in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (2.8.2)
# Requirement already satisfied: pydub in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (0.6.3)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio) (0.30.6)
# Requirement already satisfied: fsspec in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio-client==1.3.0->gradio) (2024.9.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from gradio-client==1.3.0->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.8)
# Requirement already satisfied: sniffio>=1.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.15.4)
# Requirement already satisfied: requests in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from pydantic>=2.0->gradio) (2.20.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.8.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from fastapi->gradio) (0.38.4)
# Requirement already satisfied: colorama in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\iniad\documents\github\a\iniad-ict-d-teamwork\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1.2ChatGPTのAPIキーの登録

# %%
import os

#APIキーの登録
os.environ["OPENAI_API_KEY"] = "AzhHz-8RBjB1VBrcizx4wavSFA7x8YYVs--muL-CbPodrEj2WY3Kd08cHLuRIdPLuxCrXBBk6hPqF2GiDfeYuIw"

url = "https://api.openai.iniad.org/api/v1/"

# %% [markdown]
# # 3.RAGを実装してみよう

# %% [markdown]
# ## 3.1.Document Loaderを使ってドキュメントを読み込む

# %%
# langchainのdocument_loaderからPyPDFLoaderをインポートする
from langchain.document_loaders import PyPDFLoader

# 読み込む文書の選択（適切なPathに書き換えして下さい）
loader = PyPDFLoader("date_magic.pdf")

# pagesに文書をページごとにJSON形式で格納する
pages = loader.load_and_split()

# nページ目を出力する
pages[0].page_content.replace("\n", "")
# Out:
# '失敗（1）彼氏は無視？自分の趣味を最優先「絶叫マシンが嫌いな彼と、大好きな私。当時、夢の国に何度も行っていて……『怖くないから大丈夫！』と毎回、彼を絶叫アトラクションに強制連行していました。彼の誕生日の日にも同じことをしたら、その夜に『一緒にいても楽しくない』と別れを告げられました」（2）ショッピングは女友達とすべし？「買い物が好きなので、デートは私の買い物に付き合ってもらうことがしばしば。試着して『これどうかな？』というやりとりも好きなんです。なのに『A子と出かけても女性ものの店でずっと待ってるだけで気まずいし疲れる』と言われ、喧嘩のすえ破局。それ以降、買い物は女友達と行くようになりました」（3）映え撮影に我慢の限界？「日々、SNS用の映え写真を撮るのに必死の私。デート先のレストランでも料理がきてから、料理の撮影をして……私のことを撮影してもらって……食べ始めるまでに15分くらいかかります。ある日、『デート中くらい写真撮ったり編集したりするの我慢できないの？』と怒られ、それが引き金となり破局」（27歳／フリーランス）（4）経験者発言で不愉快にさせた「元カレがすべてデート先を決めてくれていました。昔の彼と行ったことがある場所は、つい『ここ、〇年前に来たことがある～懐かしいなぁ』とポロッと言ってしまっていて。ある日『いちいち元カレの話題を出してくるの本当にストレス！』とキレられ、デート先を決めてくれなくなり、徐々にフェードアウトされました」（30歳／ネイリスト）（5）当たり前のように財布を出さなかった「いつも彼がデート代を払ってくれていたので、それが当たり前になっていて。ある日、彼が財布を忘れて。私が払えば済む話なのですが、とっさに『なんで忘れてきたのー？』と言っちゃって……。そこから彼の態度が激変。冷たくなり、最終的にフラれました」（29歳／公務員）「デートが怖くなる系失敗談」1.スポーツバーはないわ初デートで近くのバーに行くことに。彼が指定したバーに行ってみたら、スポーツバーだった。ちょうどアメフトのプレイオフをやってる日で、アメフト見ながらデートできる場所ってことで決めたっぽい。ないわーと思ってママに「スポーツバーだった。アメフト見たいらしい。キモ」ってメール送った。と思ったら、間違ってデート相手に送ってた。その場ですぐに彼がメール確認したのは気まずかった。2.酸っぱすぎる青春水にレモンを絞ったら、レモン汁が彼の目にはいってしまった。彼が痛そうにしているのを見てパニックになって余計に手に力が入って…そしたらレモンが飛んでった。それも彼の顔面に。3.鼻血を止めるにはコレがいい！初デートでワインを飲んで酔っ払って盛り上がったので、彼と一緒にうちに戻った。着いてからさっそくお互いにキス。ふと彼の顔を見たら、顔面血だらけ！怖くてパニックで「血が出てる！」って叫んだけど、血がでてたのは私だった。それもすごい量の鼻血だった。'

# %% [markdown]
# ## 3.2.Text Splitterを利用して、読み込んだ文書をチャンク化しよう

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# PDFからテキストを読み込み、一つの文字列に結合
text = "\n".join([pages.page_content.replace("\n", "") for pages in loader.load()])

# Text Splitterの設定（チャンクサイズとオーバーラップを指定）
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=512,
    chunk_overlap=20,
    length_function=len,
    add_start_index=True
)

# テキストを小さなチャンクに分割
documents = text_splitter.create_documents([text])

# 分割されたテキストの特定のチャンクを表示（例：201番目のチャンク）
print(documents[0])
# Out:
# page_content='失敗（1）彼氏は無視？自分の趣味を最優先「絶叫マシンが嫌いな彼と、大好きな私。当時、夢の国に何度も行っていて……『怖くないから大丈夫！』と毎回、彼を絶叫アトラクションに強制連行していました。彼の誕生日の日にも同じことをしたら、その夜に『一緒にいても楽しくない』と別れを告げられました」（2）ショッピングは女友達とすべし？「買い物が好きなので、デートは私の買い物に付き合ってもらうことがしばしば。試着して『これどうかな？』というやりとりも好きなんです。なのに『A子と出かけても女性ものの店でずっと待ってるだけで気まずいし疲れる』と言われ、喧嘩のすえ破局。それ以降、買い物は女友達と行くようになりました」（3）映え撮影に我慢の限界？「日々、SNS用の映え写真を撮るのに必死の私。デート先のレストランでも料理がきてから、料理の撮影をして……私のことを撮影してもらって……食べ始めるまでに15分くらいかかります。ある日、『デート中くらい写真撮ったり編集したりするの我慢できないの？』と怒られ、それが引き金となり破局」（27歳／フリーランス）（4）経験者発言で不愉快にさせた「元カレがすべてデート先を決めてくれていました。昔の彼と行っ' metadata={'start_index': 0}

# %% [markdown]
# ## 3.3.Text embedding modelsを利用して、テキストをベクトル化してみよう

# %%
from langchain_openai import OpenAIEmbeddings

embeddings_model = OpenAIEmbeddings(
    openai_api_base= url
)

# 以下の日本語をOPENAIのEnbeddingを使ってベクトル化する
embeddings = embeddings_model.embed_documents([doc.page_content for doc in documents])

# len(embeddings) は文書の数を、len(embeddings[0]) は各文書の埋め込みベクトルの次元数を表している
len(embeddings), len(embeddings[0])
# Out:
# (191, 1536)

# %%
embeddings[10]
# Out:
# [-0.03371405228972435,
#  -0.005095691420137882,
#  0.019890492781996727,
#  -0.014222700148820877,
#  -0.015699518844485283,
#  0.0020156586542725563,
#  0.0002974842500407249,
#  -0.009619281627237797,
#  -0.01870637573301792,
#  -0.03105311654508114,
#  -0.0012132201809436083,
#  0.002343286294490099,
#  -0.00810254830867052,
#  -0.0062432195991277695,
#  -0.002155357738956809,
#  0.011621635407209396,
#  0.03562992438673973,
#  -0.0008997287950478494,
#  0.019784053787589073,
#  -0.03847712650895119,
#  0.002143715973943472,
#  0.0029419967904686928,
#  -0.013497594743967056,
#  -0.0058407532051205635,
#  -0.0345921590924263,
#  0.019238563254475594,
#  0.01502098049968481,
#  -0.008335379883646965,
#  0.009093746542930603,
#  -0.017681915313005447,
#  0.02370893396437168,
#  -0.0032579826656728983,
#  0.01587248034775257,
#  -0.007823149673640728,
#  -0.016138574108481407,
#  -0.0441715270280838,
#  -0.018945859745144844,
#  0.007211134769022465,
#  0.004626701585948467,
#  0.008395250886678696,
#  0.01891924999654293,
#  -0.02237846702337265,
#  -0.008934090845286846,
#  -0.0012389980256557465,
#  -0.02370893396437168,
#  0.01813427545130253,
#  -0.04305393621325493,
#  0.007071435917168856,
#  -0.004161037504673004,
#  0.013431071303784847,
#  0.012513048946857452,
#  -0.010384300723671913,
#  -0.012825708836317062,
#  -0.0283389613032341,
#  -0.0025495088193565607,
#  0.00542830815538764,
#  -0.0005405024858191609,
#  0.012619486078619957,
#  -0.022564731538295746,
#  -0.01725616678595543,
#  0.014063043519854546,
#  0.01216712687164545,
#  -0.017642002552747726,
#  -0.010111554525792599,
#  -0.01866646111011505,
#  -0.003961467649787664,
#  -0.031319208443164825,
#  -0.0032546566799283028,
#  -0.05673114210367203,
#  0.009586019441485405,
#  0.0060636065900325775,
#  0.020329546183347702,
#  0.002175314584746957,
#  -0.015313683077692986,
#  0.035576704889535904,
#  -0.020728686824440956,
#  -0.010178077965974808,
#  0.004566830582916737,
#  -0.0009205173118971288,
#  0.0014219373697414994,
#  0.007004912476986647,
#  -0.004736464936286211,
#  0.0144621841609478,
#  -0.015380206517875195,
#  0.018413672223687172,
#  0.02116774022579193,
#  -0.02075529657304287,
#  0.029642820358276367,
#  -0.016032135114073753,
#  -0.014329137280583382,
#  -0.0035190870985388756,
#  0.010949749499559402,
#  -0.014009824953973293,
#  0.03251663222908974,
#  0.013071845285594463,
#  0.0055280933156609535,
#  -0.009659195318818092,
#  0.01942482776939869,
#  -0.008381946943700314,
#  -0.004370586480945349,
#  0.005727663636207581,
#  0.00044487512786872685,
#  -0.000350287213223055,
#  0.0021803039126098156,
#  -0.008408555760979652,
#  0.0031315884552896023,
#  0.00554139818996191,
#  -0.03520417585968971,
#  0.0044138263911008835,
#  -0.016577627509832382,
#  0.0238419808447361,
#  0.019451437518000603,
#  0.02458704262971878,
#  -0.043905433267354965,
#  -0.029562992975115776,
#  -0.0044570667669177055,
#  0.022152287885546684,
#  0.011714767664670944,
#  -0.0021137804724276066,
#  -0.018826117739081383,
#  -0.002567802555859089,
#  0.03464537858963013,
#  0.004819619469344616,
#  0.0167106743901968,
#  0.012200389057397842,
#  0.009280011989176273,
#  0.010677003301680088,
#  -0.007450619246810675,
#  0.029988741502165794,
#  0.003565653460100293,
#  0.02712823636829853,
#  -0.006070259027183056,
#  0.031984444707632065,
#  -0.008302118629217148,
#  -0.008701258338987827,
#  0.008514992892742157,
#  -0.02841879054903984,
#  -0.026569439098238945,
#  -0.012426568195223808,
#  -0.02767372876405716,
#  0.016737284138798714,
#  0.013278068043291569,
#  -0.01813427545130253,
#  -0.005880667362362146,
#  0.02929689921438694,
#  0.01833384484052658,
#  0.03658786043524742,
#  0.003954815212637186,
#  0.016564322635531425,
#  0.00016422961198259145,
#  0.0235492791980505,
#  0.0061800223775208,
#  0.002857179380953312,
#  0.007038174197077751,
#  -0.006156739313155413,
#  0.016284924000501633,
#  0.007370790932327509,
#  0.011528502218425274,
#  0.023456145077943802,
#  -0.01391669176518917,
#  0.016524408012628555,
#  0.03062736615538597,
#  0.009280011989176273,
#  -0.025185752660036087,
#  -0.009938593953847885,
#  0.03331490978598595,
#  -0.01825401745736599,
#  0.015659604221582413,
#  0.003914901055395603,
#  -0.004832923877984285,
#  -0.0011150982463732362,
#  0.004942687693983316,
#  -0.021074607968330383,
#  0.02175314724445343,
#  0.0027923190500587225,
#  0.009240098297595978,
#  0.014129566960036755,
#  0.001701335539110005,
#  -0.003981424495577812,
#  -0.009685805067420006,
#  -0.02625012770295143,
#  -0.018054446205496788,
#  0.019491352140903473,
#  0.014448879286646843,
#  0.0032330364920198917,
#  -0.005168866831809282,
#  -0.0031399037688970566,
#  0.007909630425274372,
#  0.002271773526445031,
#  -0.009506192058324814,
#  0.014728276990354061,
#  0.04672602564096451,
#  -0.003971446305513382,
#  -0.02083512395620346,
#  -0.6007328033447266,
#  -0.022245420143008232,
#  -0.009146965108811855,
#  0.007577013690024614,
#  0.004666615277528763,
#  0.0060203662142157555,
#  0.0024480605497956276,
#  0.017735134810209274,
#  -0.024693479761481285,
#  0.025944119319319725,
#  -0.010969705879688263,
#  0.02483983151614666,
#  -0.017469041049480438,
#  0.017322689294815063,
#  -0.02413468435406685,
#  -0.02075529657304287,
#  0.028658274561166763,
#  -0.010264558717608452,
#  0.0008648040238767862,
#  0.01416948065161705,
#  -0.007497185375541449,
#  0.021260874345898628,
#  -0.008834305219352245,
#  -0.003469194518402219,
#  0.027993040159344673,
#  -0.010204687714576721,
#  0.00710469763725996,
#  -0.011728072538971901,
#  -0.0015882458537817001,
#  0.027913212776184082,
#  -0.013071845285594463,
#  0.03331490978598595,
#  0.002843874739482999,
#  0.004812967032194138,
#  0.06237232685089111,
#  -0.038690000772476196,
#  0.0027923190500587225,
#  0.0298024769872427,
#  0.008488384075462818,
#  0.02601064369082451,
#  -0.020475897938013077,
#  -0.01891924999654293,
#  -0.006898474879562855,
#  -0.01054395642131567,
#  0.008315423503518105,
#  -0.017056595534086227,
#  0.015380206517875195,
#  -0.017681915313005447,
#  0.01365059893578291,
#  0.02513253502547741,
#  -0.0012373349163681269,
#  -0.011841162107884884,
#  -0.00885426253080368,
#  -0.022564731538295746,
#  0.002807286800816655,
#  -0.0019408197840675712,
#  0.0020954867359250784,
#  -0.047098558396101,
#  -0.018227407708764076,
#  -0.015859175473451614,
#  -0.0011259083403274417,
#  0.006023692432790995,
#  0.0051056696102023125,
#  -0.004946013446897268,
#  -0.002468017628416419,
#  0.012905537150800228,
#  -0.030574148520827293,
#  -0.015300378203392029,
#  0.01183451060205698,
#  0.002404820406809449,
#  -0.013364547863602638,
#  -0.009652542881667614,
#  -0.011754682287573814,
#  -0.007683450821787119,
#  0.04214921593666077,
#  0.021580185741186142,
#  0.019704226404428482,
#  0.01142206508666277,
#  -0.019730836153030396,
#  0.011076143942773342,
#  0.0005342659424059093,
#  0.012426568195223808,
#  -0.028738101944327354,
#  0.00449032848700881,
#  0.013890082947909832,
#  -0.005607921164482832,
#  -0.041324324905872345,
#  0.015513253398239613,
#  -0.000732172979041934,
#  -0.0032662982121109962,
#  -0.01229352131485939,
#  0.009865418076515198,
#  0.004194299224764109,
#  -0.008834305219352245,
#  -0.0025561610236763954,
#  0.03193122521042824,
#  -0.016950158402323723,
#  -0.020063452422618866,
#  -0.01067035086452961,
#  -0.0005658645532093942,
#  -0.006825299467891455,
#  -0.020196499302983284,
#  0.03054753877222538,
#  -0.0012373349163681269,
#  0.014595231041312218,
#  -0.0048595331609249115,
#  -0.013743731193244457,
#  0.0015433424850925803,
#  0.027514072135090828,
#  -0.0008897502557374537,
#  0.011641592718660831,
#  -0.015819260850548744,
#  -0.014089653268456459,
#  -0.004513611551374197,
#  -0.0011200874578207731,
#  -0.026662573218345642,
#  0.02054242044687271,
#  0.011555111967027187,
#  0.022511513903737068,
#  0.012805751524865627,
#  0.002971932291984558,
#  0.007390748243778944,
#  0.023868590593338013,
#  -0.00045235903235152364,
#  -0.005937212146818638,
#  0.0298024769872427,
#  0.007457271683961153,
#  -0.0038217685651034117,
#  0.009865418076515198,
#  0.0030983267351984978,
#  0.0018709702417254448,
#  -0.023815371096134186,
#  0.008049329742789268,
#  -0.015353597700595856,
#  0.016218401491642,
#  -0.01361068431288004,
#  0.009512844495475292,
#  -0.005019189324229956,
#  0.024573737755417824,
#  -0.026329955086112022,
#  -0.014475489035248756,
#  0.00012338008673395962,
#  0.011428717523813248,
#  0.026103775948286057,
#  0.004906099755316973,
#  -0.02621021308004856,
#  0.01323150098323822,
#  0.0031681761611253023,
#  -0.022032545879483223,
#  0.016284924000501633,
#  0.030680585652589798,
#  0.0001183908389066346,
#  0.00424086581915617,
#  0.028019649907946587,
#  -0.009586019441485405,
#  0.007297615520656109,
#  -0.015127417631447315,
#  -0.005837426986545324,
#  -0.009047180414199829,
#  0.017029985785484314,
#  0.0010302809532731771,
#  0.006522617768496275,
#  -0.02087503857910633,
#  -0.0067554498091340065,
#  0.012539657764136791,
#  -0.017974618822336197,
#  0.021819669753313065,
#  0.0033860402181744576,
#  -0.011827858164906502,
#  -0.025611503049731255,
#  -0.0013179945526644588,
#  -0.015766041353344917,
#  -0.01010490208864212,
#  0.004600092303007841,
#  -0.008974004536867142,
#  -0.007344181649386883,
#  0.008834305219352245,
#  0.002147042192518711,
#  -0.021846279501914978,
#  0.006725514307618141,
#  0.0023000461515039206,
#  -0.03046770952641964,
#  -0.02249820902943611,
#  0.0043173679150640965,
#  0.03837068751454353,
#  -0.007244396489113569,
#  0.007151263765990734,
#  0.01850680634379387,
#  -0.005591290537267923,
#  0.01909221149981022,
#  -0.009532800875604153,
#  0.005162214860320091,
#  0.007031521759927273,
#  0.008302118629217148,
#  0.007630232255905867,
#  -0.023575887084007263,
#  0.04909425973892212,
#  0.0106038274243474,
#  -0.004753096029162407,
#  0.03813120350241661,
#  -0.00411447137594223,
#  0.005185497924685478,
#  -0.003351115621626377,
#  -0.003347789403051138,
#  0.022152287885546684,
#  -0.025811074301600456,
#  0.00954610574990511,
#  -0.006186674814671278,
#  0.03597584739327431,
#  -0.017854876816272736,
#  -0.01870637573301792,
#  -0.016151877120137215,
#  -0.012912188656628132,
#  0.0007458934560418129,
#  0.028738101944327354,
#  0.0298024769872427,
#  -0.003482499159872532,
#  0.026476306840777397,
#  0.00037835174589417875,
#  0.023948417976498604,
#  0.003934858366847038,
#  -0.010217991657555103,
#  -0.014116262085735798,
#  -0.019651008769869804,
#  -0.007443966809660196,
#  -0.02374884858727455,
#  0.006891822908073664,
#  -0.003445911454036832,
#  -0.011701463721692562,
#  -0.01427591871470213,
#  -0.014448879286646843,
#  -0.006559205707162619,
#  0.0038417254108935595,
#  0.027859993278980255,
#  -0.0016980094369500875,
#  -0.03884965553879738,
#  0.03666768968105316,
#  -0.027514072135090828,
#  0.030201617628335953,
#  0.010198035277426243,
#  0.007237744517624378,
#  0.020702077075839043,
#  0.024360863491892815,
#  -0.012725923210382462,
#  -0.006971650756895542,
#  0.008874219842255116,
#  0.027021799236536026,
#  0.006535922642797232,
#  -0.009466277435421944,
#  0.038237642496824265,
#  -0.007776583544909954,
#  0.02370893396437168,
#  -0.004460392985492945,
#  -0.010929792188107967,
#  -0.003535717958584428,
#  -0.0443577915430069,
#  0.003138240659609437,
#  0.017202947288751602,
#  0.029642820358276367,
#  0.029163852334022522,
#  0.020475897938013077,
#  0.020848428830504417,
#  0.0037120049819350243,
#  -0.013996520079672337,
#  0.029270289465785027,
#  -0.0020505832508206367,
#  0.01679050177335739,
#  -0.013570770621299744,
#  -0.021260874345898628,
#  -0.0009055495611391962,
#  0.009027223102748394,
#  -0.01504758931696415,
#  -0.008548255078494549,
#  -0.006389571353793144,
#  0.017163032665848732,
#  -0.0065991198644042015,
#  -0.0035689796786755323,
#  -0.01129567064344883,
#  0.025638112798333168,
#  0.007137959357351065,
#  -0.020076757296919823,
#  -0.04097840562462807,
#  0.018360454589128494,
#  0.006951693911105394,
#  -0.00498925382271409,
#  -0.024706784635782242,
#  0.014728276990354061,
#  -0.015885785222053528,
#  -0.0044138263911008835,
#  0.01741582155227661,
#  -0.0220857635140419,
#  0.02950977347791195,
#  0.013011974282562733,
#  0.014714973047375679,
#  -0.01360403187572956,
#  0.019345000386238098,
#  0.04350629448890686,
#  -0.006449442356824875,
#  -0.027487462386488914,
#  -0.03645481541752815,
#  0.005268651992082596,
#  -0.01291884109377861,
#  -0.025238972157239914,
#  -0.015114112757146358,
#  0.026848837733268738,
#  -0.00547820096835494,
#  -0.02333640307188034,
#  -0.021526968106627464,
#  -0.015446729958057404,
#  -0.02509262040257454,
#  0.011728072538971901,
#  -0.012426568195223808,
#  -0.011262409389019012,
#  0.006160065531730652,
#  -0.008654692210257053,
#  0.016511105000972748,
#  0.01645788550376892,
#  -0.003432606579735875,
#  0.010889878496527672,
#  -0.016484495252370834,
#  -0.0022884043864905834,
#  0.005624552257359028,
#  -0.03972776606678963,
#  -0.010823355056345463,
#  0.09382458031177521,
#  -0.013863473199307919,
#  -0.008348684757947922,
#  -0.006958345882594585,
#  -0.0040113599970936775,
#  -0.020435983315110207,
#  -0.022152287885546684,
#  -0.013091802597045898,
#  0.01339781004935503,
#  -0.003208090318366885,
#  0.04507624730467796,
#  -0.01289888471364975,
#  0.012785794213414192,
#  -0.00424086581915617,
#  0.011847814545035362,
#  -0.030494319275021553,
#  0.007197830360382795,
#  0.0016938516637310386,
#  0.025784464552998543,
#  9.094994311453775e-05,
#  0.004061252810060978,
#  0.006559205707162619,
#  -0.006392897106707096,
#  0.01687033101916313,
#  -0.010936444625258446,
#  -0.0029968784656375647,
#  0.0047032032161951065,
#  0.02183297462761402,
#  0.0244273878633976,
#  -0.013783645816147327,
#  -0.012652748264372349,
#  -0.01542012020945549,
#  -0.003888291772454977,
#  0.024932963773608208,
#  -0.0010519010247662663,
#  -0.01264609582722187,
#  -0.0014269265811890364,
#  0.03528400510549545,
#  -0.005288609303534031,
#  0.010410909540951252,
#  0.01649780012667179,
#  0.02237846702337265,
#  0.02058233506977558,
#  -0.0004502801748458296,
#  0.0011408760910853744,
#  -0.022099068388342857,
#  0.02204584889113903,
#  -0.005288609303534031,
#  -0.011621635407209396,
#  -0.018772900104522705,
#  0.03405997157096863,
#  0.0009354851208627224,
#  -0.022019241005182266,
#  -0.016284924000501633,
#  0.006525943987071514,
#  0.004796335939317942,
#  -0.000597878941334784,
#  -0.02146044373512268,
#  -0.0077366698533296585,
#  0.03105311654508114,
#  0.007596970535814762,
#  -0.03206427022814751,
#  0.00599043071269989,
#  -0.01596561260521412,
#  -0.015939002856612206,
#  -0.03339473903179169,
#  0.005647835321724415,
#  -0.012306826189160347,
#  0.0021836301311850548,
#  0.008648039773106575,
#  0.013757036067545414,
#  -0.017229557037353516,
#  -0.023229965940117836,
#  -0.012978712096810341,
#  0.013876778073608875,
#  0.003695374121889472,
#  0.022112373262643814,
#  -0.006582488771528006,
#  -0.019038992002606392,
#  0.0076036229729652405,
#  -0.010078293271362782,
#  -0.02659604884684086,
#  -0.004064579028636217,
#  -0.02020980417728424,
#  -0.015287074260413647,
#  0.019903797656297684,
#  -0.0025811074301600456,
#  -0.0004723160236608237,
#  -0.007384095806628466,
#  0.015393511392176151,
#  0.023828675970435143,
#  5.4881791584193707e-05,
#  0.004097840283066034,
#  0.012852317653596401,
#  -0.005754272919148207,
#  -0.011415412649512291,
#  -0.018972469493746758,
#  0.012945450842380524,
#  0.014568621292710304,
#  0.004789683502167463,
#  0.006422832608222961,
#  -0.03597584739327431,
#  -0.017282774671912193,
#  -0.00524204270914197,
#  0.0054615698754787445,
#  -0.0022917306050658226,
#  -0.0008007752476260066,
#  0.010923139750957489,
#  0.014063043519854546,
#  0.0011766323586925864,
#  0.010537303984165192,
#  -0.019318390637636185,
#  -0.006422832608222961,
#  0.019637703895568848,
#  0.0025877596344798803,
#  0.03158530220389366,
#  -0.012799099087715149,
#  0.03541705012321472,
#  -0.008408555760979652,
#  -0.02479991875588894,
#  0.007876369170844555,
#  0.0024663545191287994,
#  0.03084024041891098,
#  0.0260904710739851,
#  -0.02879132144153118,
#  0.0030018677935004234,
#  -0.009699109941720963,
#  -0.03472520783543587,
#  -0.006033671088516712,
#  0.011901033110916615,
#  0.03501791134476662,
#  0.0244273878633976,
#  -0.0066889263689517975,
#  -0.041031625121831894,
#  -0.02142052911221981,
#  0.004972623195499182,
#  -0.025771159678697586,
#  0.00013117579510435462,
#  -0.025438541546463966,
#  -0.02312352880835533,
#  -0.011428717523813248,
#  -0.03339473903179169,
#  0.0016805470222607255,
#  -0.004633353557437658,
#  0.044277966022491455,
#  -0.02855183742940426,
#  -0.03664107993245125,
#  0.004516937769949436,
#  -0.024360863491892815,
#  0.01439566072076559,
#  0.022524818778038025,
#  0.002353264717385173,
#  -0.02146044373512268,
#  0.014848019927740097,
#  0.015406816266477108,
#  -0.02863166481256485,
#  -0.005913929082453251,
#  -0.010577218607068062,
#  -0.005913929082453251,
#  0.008787739090621471,
#  0.008914133533835411,
#  -0.008448469452559948,
#  -0.0047464435920119286,
#  -0.009433016180992126,
#  0.006635707803070545,
#  0.016976768150925636,
#  -0.01774843968451023,
#  -0.003472520736977458,
#  -0.029429946094751358,
#  0.03355439379811287,
#  0.01129567064344883,
#  0.030866850167512894,
#  -0.009785589762032032,
#  0.006871865596622229,
#  -0.022099068388342857,
#  0.029057415202260017,
#  -0.0027790144085884094,
#  0.011934295296669006,
#  -0.009865418076515198,
#  -0.03805137798190117,
#  0.018400369212031364,
#  -0.030148398131132126,
#  -0.008495036512613297,
#  -0.004134428221732378,
#  -0.009160269983112812,
#  -0.008475079201161861,
#  -0.005291935056447983,
#  0.0031548715196549892,
#  0.03392692655324936,
#  -0.016191791743040085,
#  0.0135840754956007,
#  -0.030068570747971535,
#  0.006123477593064308,
#  0.003103315830230713,
#  0.007437314372509718,
#  -0.010849963873624802,
#  -0.023522669449448586,
#  -0.012552962638437748,
#  0.02663596346974373,
#  0.02042267844080925,
#  0.006273155100643635,
#  0.00566779263317585,
#  -0.011155971325933933,
#  -0.014515402726829052,
#  -0.016936853528022766,
#  0.01754886843264103,
#  -0.02341623231768608,
#  -0.02759389951825142,
#  0.013184934854507446,
#  -0.017575478181242943,
#  0.0013312991941347718,
#  -0.018200797960162163,
#  -0.029908914119005203,
#  -0.035576704889535904,
#  -0.008308771066367626,
#  0.010424214415252209,
#  -0.031239381060004234,
#  0.023655716329813004,
#  -0.006382918916642666,
#  -0.03004196099936962,
#  -0.012932145968079567,
#  -0.02325657568871975,
#  0.026822227984666824,
#  -0.002085508080199361,
#  0.03163852170109749,
#  0.03491147235035896,
#  -0.003236362710595131,
#  -0.010410909540951252,
#  -0.06364957243204117,
#  0.005118974484503269,
#  -0.0021453790832310915,
#  0.003781854407861829,
#  0.0447569340467453,
#  -0.006156739313155413,
#  -0.00641618063673377,
#  0.005923907272517681,
#  0.011155971325933933,
#  -0.043905433267354965,
#  -0.03291577100753784,
#  0.032117489725351334,
#  0.017442431300878525,
#  0.013184934854507446,
#  -0.01749565079808235,
#  0.016857026144862175,
#  -0.003509108442813158,
#  0.010390953160822392,
#  0.0014119588304311037,
#  0.002406483516097069,
#  -0.018786203116178513,
#  -0.025105925276875496,
#  -0.026409784331917763,
#  0.010716916993260384,
#  0.004131102003157139,
#  0.017229557037353516,
#  0.009865418076515198,
#  -0.0266758780926466,
#  -0.004337324760854244,
#  -0.025864291936159134,
#  0.004267475102096796,
#  0.015433425083756447,
#  0.0042508444748818874,
#  0.03491147235035896,
#  -0.0021503684110939503,
#  0.009133661165833473,
#  -0.010743526741862297,
#  -0.0015957297291606665,
#  -0.011375498957931995,
#  -0.027021799236536026,
#  -0.010657045990228653,
#  0.051356054842472076,
#  0.010776787996292114,
#  0.018160883337259293,
#  -0.010577218607068062,
#  -0.005644509103149176,
#  0.004467045422643423,
#  0.021806364879012108,
#  0.009200184606015682,
#  -0.0070913927629590034,
#  -0.01391669176518917,
#  -0.0042574964463710785,
#  0.030866850167512894,
#  0.0077832359820604324,
#  0.007011564914137125,
#  -0.013637294061481953,
#  -0.018187493085861206,
#  -0.020076757296919823,
#  -0.00020830135326832533,
#  0.011328932829201221,
#  0.006825299467891455,
#  -0.025531675666570663,
#  -0.021526968106627464,
#  -0.026196908205747604,
#  -0.0049692969769239426,
#  0.0024247774854302406,
#  -0.00561457360163331,
#  -0.005178845487535,
#  0.0029536383226513863,
#  0.010743526741862297,
#  -0.04018012434244156,
#  0.024014942348003387,
#  0.0015957297291606665,
#  0.0030184986535459757,
#  -0.010457475669682026,
#  0.001392001868225634,
#  -0.0028172654565423727,
#  0.005188824143260717,
#  0.009566063061356544,
#  -0.017522258684039116,
#  -0.00641618063673377,
#  -0.01950465701520443,
#  0.005807491485029459,
#  0.0019108842825517058,
#  0.002923702821135521,
#  0.016684064641594887,
#  0.022697778418660164,
#  0.004440436139702797,
#  0.018613243475556374,
#  -0.01546003483235836,
#  -0.028764711692929268,
#  -0.007590318098664284,
#  -0.00098205148242414,
#  0.01875959523022175,
#  -0.004693225026130676,
#  -0.042521748691797256,
#  0.010304472409188747,
#  0.005651161540299654,
#  -0.00761692738160491,
#  -0.010790092870593071,
#  -0.023349707946181297,
#  -0.026649268344044685,
#  -0.016072049736976624,
#  0.005591290537267923,
#  -0.02012997679412365,
#  -0.016843721270561218,
#  -0.023575887084007263,
#  -0.002937007462605834,
#  0.0004436278250068426,
#  0.01439566072076559,
#  0.0072310920804739,
#  -0.006496008485555649,
#  0.0013861809857189655,
#  0.0328359417617321,
#  0.008288813754916191,
#  -0.002433092799037695,
#  0.007876369170844555,
#  -0.011994166299700737,
#  -0.0007546246633864939,
#  -0.012619486078619957,
#  -0.032490022480487823,
#  0.0014127903850749135,
#  -0.011242452077567577,
#  0.046779245138168335,
#  0.017854876816272736,
#  -0.011874424293637276,
#  -0.018160883337259293,
#  -0.011056186631321907,
#  -0.022205505520105362,
#  -0.01483471505343914,
#  -0.029536383226513863,
#  0.018812812864780426,
#  0.038823045790195465,
#  -0.02396172285079956,
#  0.012572919949889183,
#  0.015034285373985767,
#  0.02087503857910633,
#  0.011069491505622864,
#  -0.008388598449528217,
#  -0.009552758187055588,
#  0.008694606833159924,
#  -0.040446218103170395,
#  0.0036787432618439198,
#  0.02038276568055153,
#  -0.04055265709757805,
#  -0.008601473644375801,
#  -0.0006207463447935879,
#  -0.007523794658482075,
#  0.014675058424472809,
#  0.0075370995327830315,
#  -0.019491352140903473,
#  -0.01498106587678194,
#  0.01077013649046421,
#  -0.025571588426828384,
#  0.006080237217247486,
#  -0.013424418866634369,
#  -0.00455352570861578,
#  -0.035656534135341644,
#  -0.013351242989301682,
#  -0.0026359891053289175,
#  0.021034695208072662,
#  -0.011455327272415161,
#  0.008934090845286846,
#  0.006851908750832081,
#  -0.01692354865372181,
#  0.013078497722744942,
#  -0.020369460806250572,
#  -0.019517961889505386,
#  -0.018466891720891,
#  -0.0020871711894869804,
#  0.010144815780222416,
#  -0.005095691420137882,
#  -0.023442840203642845,
#  0.02988230437040329,
#  0.01587248034775257,
#  -0.010257906280457973,
#  -0.0034226281568408012,
#  0.006565858144313097,
#  0.017615392804145813,
#  0.008614778518676758,
#  0.019810663536190987,
#  -0.019704226404428482,
#  0.02575785480439663,
#  -0.0018560024909675121,
#  0.0038051377050578594,
#  -0.02446730062365532,
#  0.008381946943700314,
#  0.01967761665582657,
#  -0.011056186631321907,
#  -0.018599938601255417,
#  0.03408658131957054,
#  0.029855694621801376,
#  -0.009758980944752693,
#  -0.005345154087990522,
#  -0.014661754481494427,
#  0.0024380821269005537,
#  -0.008734520524740219,
#  -0.03405997157096863,
#  0.024014942348003387,
#  -0.03033466264605522,
#  -0.023908505216240883,
#  -0.006725514307618141,
#  -0.0074040526524186134,
#  -0.01283236127346754,
#  0.005631204694509506,
#  -0.02487974613904953,
#  -0.02337631769478321,
#  -0.018493501469492912,
#  0.2929157614707947,
#  -0.020276328548789024,
#  0.011595025658607483,
#  0.02142052911221981,
#  -0.001183284679427743,
#  0.026689182966947556,
#  0.018732985481619835,
#  0.0001290969375986606,
#  0.009260055609047413,
#  0.012652748264372349,
#  -0.013717122375965118,
#  -0.007696755696088076,
#  -0.021660014986991882,
#  0.0003014340763911605,
#  0.019930405542254448,
#  -0.03262306749820709,
#  -0.00780319282785058,
#  -0.018520111218094826,
#  -0.011528502218425274,
#  -0.030866850167512894,
#  0.013956606388092041,
#  0.004566830582916737,
#  0.0010602164547890425,
#  -0.01122914720326662,
#  0.011136014945805073,
#  0.030946679413318634,
#  -0.00371533096767962,
#  0.0025860965251922607,
#  0.009539453312754631,
#  0.0022218809463083744,
#  -0.017269471660256386,
#  -0.016950158402323723,
#  0.011408760212361813,
#  -0.014661754481494427,
#  -0.0005953842774033546,
#  0.0052619995549321175,
#  0.022072458639740944,
#  0.024108074605464935,
#  0.01659093238413334,
#  0.019611094146966934,
#  0.02217889577150345,
#  0.009506192058324814,
#  0.011468631215393543,
#  -0.02050250768661499,
#  -0.009000614285469055,
#  0.013284719549119473,
#  ...]

# %% [markdown]
# ## 3.4.ベクトルDBへ保存をしてみよう

# %%
from langchain.vectorstores import Chroma

# ChromaDBへの値の保存
db = Chroma.from_texts([doc.page_content for doc in documents], embeddings_model)

# %% [markdown]
# ## 3.5.ベクトル検索をしてみよう

# %%
# テキストクエリを受け取り、Chromaベクトルストア内での類似したドキュメントを検索する。
# 返されるドキュメントは、クエリとの類似度に基づいてランキングされ、最も類似した上位のドキュメントが返される。オプションのパラメータkを指定すると、返されるドキュメントの数を制限することができる。
query = "別れる"
k = 3

# similarity_searchメソッドの呼び出し
results = db.similarity_search_with_score(query, k)

# 結果の表示
for result in results:
    print(result)
# Out:
# (Document(page_content='お店に入るなりメニューをお互いにみますがそれでも無言。ベルで呼ばなくても店員さんがきて注文を聞かれたので、まだ決まっていませんでしたが適当にたのみました。ケータイをいじったりして会話もないままうどんが運ばれ、そのまま食事。お店を出た後どこか行くわけでもなく私の家に送られたので、私も無言のまま帰宅。１時間ほどで終わりました。会話のない最低なクリスマスデートでした。20.女心は秋の空当時１7歳の僕が付き合っていた彼女は、２つ年上でした。そして僕の先輩の元カノでした。その時はそう思ってたのですが、、、ある日の休日デートをしていると、後ろから誰かに名前を呼ばれ振り返ると先輩でした。挨拶をするとと同時に目の前が真っ白になりました。自分は何が起きたかわからず呆然としていると漫画やテレビなどでよく見る『てめえ俺の女となにしてんだ』の一言が飛んできました。？？？その時は何のことやらやり返そうとしたら彼女に止められ、タクシーにつめられ近くの駅で降りるとまさかの三股宣言され、泣きながら帰ったのが今では笑える思い出です。21.最悪な誕生日彼はかなりの浮気症でした。なので他の女との関係が発覚するたびに別れたり付き合ったりを繰りかえ'), 0.36542636156082153)
# (Document(page_content='するたびに別れたり付き合ったりを繰りかえしていました。そんな彼と私の誕生日の日にディズニーランドに行ったのですが、入場する前にボン・ヴォヤージュでお土産を見ていました。すると彼はペアのストラップを購入していました。私は自分とのだと思って「私もお金払うよ」と言ったのですが「お前とのじゃないよ」と言われて入場前に大ゲンカしました。途中まで帰りましたが、結局仲直りしてディズニーランドに行きましたが気分は最悪でした。22.私の携帯のパスワードを解除してメッセージを読んでいた彼氏婚活サイトで出会った真面目な彼氏の話です。まさか自分の彼氏がそんなことをするような人だとちっとも疑ってはいなかったのですが、彼の家に遊びに行って私がトイレに行っている隙に私の携帯の着信メッセージを見られていました。たまたま男友達からのメッセージを彼が見て、これは誰なんだと逆ギレをされました。'), 0.3659428656101227)
# (Document(page_content='●周囲を気にせず二人きりで密着して過ごせる場所に行きたいと思うので。（東京都／２９歳）●恋人の状態なら家に呼んでもらえるのは嬉しい。（埼玉県／２７歳）'), 0.36929941177368164)

# %%
# 埋め込みベクトルembeddingを受け取り、Chromaベクトルストア内での類似したドキュメントを検索する
embedding_vector = OpenAIEmbeddings(openai_api_base= url).embed_query(query)
results = db.similarity_search_by_vector_with_relevance_scores(embedding_vector, k)

# 結果の表示
for result in results:
    print(result)
# Out:
# (Document(page_content='お店に入るなりメニューをお互いにみますがそれでも無言。ベルで呼ばなくても店員さんがきて注文を聞かれたので、まだ決まっていませんでしたが適当にたのみました。ケータイをいじったりして会話もないままうどんが運ばれ、そのまま食事。お店を出た後どこか行くわけでもなく私の家に送られたので、私も無言のまま帰宅。１時間ほどで終わりました。会話のない最低なクリスマスデートでした。20.女心は秋の空当時１7歳の僕が付き合っていた彼女は、２つ年上でした。そして僕の先輩の元カノでした。その時はそう思ってたのですが、、、ある日の休日デートをしていると、後ろから誰かに名前を呼ばれ振り返ると先輩でした。挨拶をするとと同時に目の前が真っ白になりました。自分は何が起きたかわからず呆然としていると漫画やテレビなどでよく見る『てめえ俺の女となにしてんだ』の一言が飛んできました。？？？その時は何のことやらやり返そうとしたら彼女に止められ、タクシーにつめられ近くの駅で降りるとまさかの三股宣言され、泣きながら帰ったのが今では笑える思い出です。21.最悪な誕生日彼はかなりの浮気症でした。なので他の女との関係が発覚するたびに別れたり付き合ったりを繰りかえ'), 0.36542636156082153)
# (Document(page_content='するたびに別れたり付き合ったりを繰りかえしていました。そんな彼と私の誕生日の日にディズニーランドに行ったのですが、入場する前にボン・ヴォヤージュでお土産を見ていました。すると彼はペアのストラップを購入していました。私は自分とのだと思って「私もお金払うよ」と言ったのですが「お前とのじゃないよ」と言われて入場前に大ゲンカしました。途中まで帰りましたが、結局仲直りしてディズニーランドに行きましたが気分は最悪でした。22.私の携帯のパスワードを解除してメッセージを読んでいた彼氏婚活サイトで出会った真面目な彼氏の話です。まさか自分の彼氏がそんなことをするような人だとちっとも疑ってはいなかったのですが、彼の家に遊びに行って私がトイレに行っている隙に私の携帯の着信メッセージを見られていました。たまたま男友達からのメッセージを彼が見て、これは誰なんだと逆ギレをされました。'), 0.36594289541244507)
# (Document(page_content='●周囲を気にせず二人きりで密着して過ごせる場所に行きたいと思うので。（東京都／２９歳）●恋人の状態なら家に呼んでもらえるのは嬉しい。（埼玉県／２７歳）'), 0.36929944157600403)

# %% [markdown]
# ## 3.6.AWSドキュメントをベクトルDB保存し、ベクトル検索してみよう

# %%
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# OpenAI埋め込みモデルのインスタンスを作成
embeddings_model = OpenAIEmbeddings(
    openai_api_base= url
)


# PDFファイルの読み込み
loader = PyPDFLoader("/content/security-reference-architecture.pdf")
text = "\n".join([page.page_content for page in loader.load()])

# Text Splitterの設定
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=20,
    length_function=len,
    add_start_index=True
)

# テキストの分割
documents = text_splitter.create_documents([text])

# ベクトル化したテキストをChromaDBに保存する
db = Chroma.from_documents(documents,embeddings_model)
# Out:
# C:\Users\iniad\AppData\Local\Temp\ipykernel_24548\2193606141.py:9: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   embeddings_model = OpenAIEmbeddings(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 15
#       9 embeddings_model = OpenAIEmbeddings(
#      10     openai_api_base= url
#      11 )
#      14 # PDFファイルの読み込み
# ---> 15 loader = PyPDFLoader("/content/security-reference-architecture.pdf")
#      16 text = "\n".join([page.page_content for page in loader.load()])
#      18 # Text Splitterの設定
#
# File c:\Users\iniad\Documents\GitHub\a\iniad-ict-d-teamwork\.venv\Lib\site-packages\langchain_community\document_loaders\pdf.py:241, in PyPDFLoader.__init__(self, file_path, password, headers, extract_images, extraction_mode, extraction_kwargs)
#     237 except ImportError:
#     238     raise ImportError(
#     239         "pypdf package not found, please install it with `pip install pypdf`"
#     240     )
# --> 241 super().__init__(file_path, headers=headers)
#     242 self.parser = PyPDFParser(
#     243     password=password,
#     244     extract_images=extract_images,
#     245     extraction_mode=extraction_mode,
#     246     extraction_kwargs=extraction_kwargs,
#     247 )
#
# File c:\Users\iniad\Documents\GitHub\a\iniad-ict-d-teamwork\.venv\Lib\site-packages\langchain_community\document_loaders\pdf.py:117, in BasePDFLoader.__init__(self, file_path, headers)
#     115         self.file_path = str(temp_pdf)
#     116 elif not os.path.isfile(self.file_path):
# --> 117     raise ValueError("File path %s is not a valid file or url" % self.file_path)
#
# ValueError: File path /content/security-reference-architecture.pdf is not a valid file or url

# %%
query = "Security Lakeとは何ですか"
docs = db.similarity_search(query)
print(docs)

# %%
embedding_vector = OpenAIEmbeddings(openai_api_base= url).embed_query(query)
docs = db.similarity_search_by_vector(embedding_vector)
print(docs)

# %% [markdown]
# ## 3.7.AWSドキュメントを利用したRAGを実装してみよう

# %%
# 必要なライブラリをインポートする
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# retriever(検索対象のVectorDB)の定義
retriever = db.as_retriever()

# テンプレートを定義
template = """Answer the question based only on the following context:

{context}

Question: {question}
"""
# promptを定義。これがLLMの入力になる
prompt = ChatPromptTemplate.from_template(template)

# LLMを定義。今回はChatGPTの4o-miniを利用する
llm = ChatOpenAI(
    model_name="gpt-4o-mini",
    temperature=0,
    openai_api_base= url,
    verbose=True
    )


def format_docs(docs):
    return "\n\n".join([d.page_content for d in docs])

# Chainを定義。これはおまじないだと思って下さい。
chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser(verbose=True)
    )

# 問い合わせしたい内容を定義
input = "Security Lakeとは何ですか"

references = retriever.get_relevant_documents(input)
output_by_retriever = chain.invoke(input)
output_by_simple_llm = llm.invoke(input)

# 参考にした箇所を表示します。
# 情報の取得元や参照した文献など、生成された回答の背景にある情報源が含まれています
print("参考にした箇所: " + str(references))


# 検索結果を基に生成された回答や内容が含まれています
print("RAGの出力結果: " + str(output_by_retriever))

# シンプルな言語モデルのみを使用して生成された回答や内容を含んでいます
print("シンプルなLLM（ChatGPT）の出力結果: " + str(output_by_simple_llm))

# %% [markdown]
# ## 3.8.演習2：RAGを使ってみよう

# %%
# 問い合わせしたい内容を定義
input = "{PDFに含まれている内容を問い合わせます}"

references = retriever.get_relevant_documents(input)
output_by_retriever = chain.invoke(input)
output_by_simple_llm = llm.invoke(input)

# 参考にした箇所を表示します。
# 情報の取得元や参照した文献など、生成された回答の背景にある情報源が含まれています
print("参考にした箇所: " + str(references))


# 検索結果を基に生成された回答や内容が含まれています
print("RAGの出力結果: " + str(output_by_retriever))

# シンプルな言語モデルのみを使用して生成された回答や内容を含んでいます
print("シンプルなLLM（ChatGPT）の出力結果: " + str(output_by_simple_llm))

# %% [markdown]
# # 4.RAGを利用したChatbot

# %%
import gradio as gr
from langchain_core.runnables import RunnablePassthrough
from langchain.llms import Ollama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# ドキュメントの読み込みとベクトルストアの作成
retriever = db.as_retriever(search_kwargs={"k": 3})

# テンプレートとプロンプトの定義
template_with_context = """以下のcontextのみに基づいて質問にできるだけ詳しく箇条書きで答えなさい。:
{context}
質問: {question}
"""
template_without_context = """質問にできるだけ詳しく箇条書きで答えなさい。:
質問: {question}
"""

prompt_with_context = ChatPromptTemplate.from_template(template_with_context)
prompt_without_context = ChatPromptTemplate.from_template(template_without_context)

# LLMの定義（ストリーミング対応）
llm = ChatOpenAI(
    model_name="gpt-4o-mini",
    temperature=0,
    openai_api_base= url,
    verbose=True)

def format_docs(docs):
    return "\n\n".join([d.page_content for d in docs])

# Chainの定義
chain_with_context = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt_with_context
    | llm
    | StrOutputParser()
)

chain_without_context = (
    {"question": RunnablePassthrough()}
    | prompt_without_context
    | llm
    | StrOutputParser()
)

def process_query_with_rag(query):
    # 関連ドキュメントの取得
    relevant_docs = retriever.get_relevant_documents(query)
    sources = [doc.page_content for doc in relevant_docs]

    # 回答の生成（ストリーミング）
    answer = ""
    for chunk in chain_with_context.stream(query):
        answer += chunk
        yield answer, "\n\n".join(sources)

def process_query_without_rag(query):
    # 回答の生成（ストリーミング）
    answer = ""
    for chunk in chain_without_context.stream(query):
        answer += chunk
        yield answer, "なし"

# Gradioインターフェースの定義
with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            gr.Markdown("## RAGあり")
            input_text_with_rag = gr.Textbox(lines=2, placeholder="質問を入力してください...")
            output_text_with_rag = gr.Markdown(label="回答")
            sources_with_rag = gr.Textbox(label="参照ソース")
            rag_button = gr.Button("RAGありで質問する")
            rag_button.click(fn=process_query_with_rag, inputs=input_text_with_rag, outputs=[output_text_with_rag, sources_with_rag])

        with gr.Column():
            gr.Markdown("## RAGなし")
            input_text_without_rag = gr.Textbox(lines=2, placeholder="質問を入力してください...")
            output_text_without_rag = gr.Markdown(label="回答")
            sources_without_rag = gr.Textbox(label="参照ソース")
            no_rag_button = gr.Button("RAGなしで質問する")
            no_rag_button.click(fn=process_query_without_rag, inputs=input_text_without_rag, outputs=[output_text_without_rag, sources_without_rag])

demo.launch()
